# %% [markdown]
# ## This notebook merges the remake data from IMDB and TMDB together, then changes a few of the columns to make them easier to use.

# %%
import urllib.request
import json
import pandas as pd
from datetime import datetime
import numpy as np
from loguru import logger
from IPython.display import clear_output
import requests
import re
from scipy import stats

tmdb_key = "ad63716b3506edd1aaa3aef6c8ebd46b"

pd.options.mode.chained_assignment = None  # default='warn'

# %%
sequels_imdb_df = pd.read_csv("SequelOutput.csv")
sequels_imdb_df.head()
# Out:
#      imdb_id             Movie Budget Movie Box Office US/CA  \
# 0  tt0795421  $52,000,000 (estimated)           $144,169,664
# 1  tt6911608  $75,000,000 (estimated)           $120,634,935
# 2  tt0078748  $11,000,000 (estimated)            $81,900,459
# 3  tt0090605  $18,500,000 (estimated)            $85,160,248
# 4  tt0103644  $50,000,000 (estimated)            $55,473,545
#
#   Movie Box Office Worldwide Movie Length  Movie Rating Movie Director Names  \
# 0               $694,476,782       1h 48m           6.5       Phyllida Lloyd
# 1               $402,264,843       1h 54m           6.6            Ol Parker
# 2               $106,285,522       1h 57m           8.5         Ridley Scott
# 3               $131,060,248       2h 17m           8.4        James Cameron
# 4               $159,814,498       1h 54m           6.4        David Fincher
#
#                        Movie Director Links  \
# 0  ['https://www.imdb.com/name/nm1630273/']
# 1  ['https://www.imdb.com/name/nm0662530/']
# 2  ['https://www.imdb.com/name/nm0000631/']
# 3  ['https://www.imdb.com/name/nm0000116/']
# 4  ['https://www.imdb.com/name/nm0000399/']
#
#                                     Movie Cast Names  \
# 0      Meryl Streep, Pierce Brosnan, Amanda Seyfried
# 1          Lily James, Amanda Seyfried, Meryl Streep
# 2          Sigourney Weaver, Tom Skerritt, John Hurt
# 3       Sigourney Weaver, Michael Biehn, Carrie Henn
# 4  Sigourney Weaver, Charles S. Dutton, Charles D...
#
#                                     Movie Cast Links  \
# 0  ['https://www.imdb.com/name/nm0000658/', 'http...
# 1  ['https://www.imdb.com/name/nm4141252/', 'http...
# 2  ['https://www.imdb.com/name/nm0000244/', 'http...
# 3  ['https://www.imdb.com/name/nm0000244/', 'http...
# 4  ['https://www.imdb.com/name/nm0000244/', 'http...
#
#                                         Movie Awards
# 0  Judy Craymer\n\nGary Goetzman\n\nPhyllida Lloy...
# 1   Excellence in Contemporary Film\nMichele Clapton
# 2  Best Effects, Visual Effects\nH.R. Giger\n\nCa...
# 3  Best Effects, Sound Effects Editing\nDon Sharp...
# 4  Best Effects, Visual Effects\nRichard Edlund\n...

# %%
sequels_tmdb_df = pd.read_csv("sequels_tmdb_data.csv", index_col=[0])
sequels_tmdb_df.head()
# Out:
#                          title    imdb_id  tmdb_id release_date  is_sequel  \
# 0                   Mamma Mia!  tt0795421    11631   2008-07-03          0
# 1  Mamma Mia! Here We Go Again  tt6911608   458423   2018-07-09          1
# 2                        Alien  tt0078748      348   1979-05-25          0
# 3                       Aliens  tt0090605      679   1986-07-18          1
# 4                       Alien³  tt0103644     8077   1992-05-22          1
#
#    runtime  vote_average  vote_count  popularity    budget    revenue  \
# 0      108         6.966        5868      29.600  52000000  609841637
# 1      113         7.136        3039      19.692  75000000  395044706
# 2      117         8.142       12773      47.437  11000000  104931801
# 3      137         7.921        8445      40.290  18500000  183316455
# 4      114         6.348        4894      19.691  50000000  159773545
#
#                                               genres original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...                en
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...                en
# 2  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...                en
# 3  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...                en
# 4  [{'id': 878, 'name': 'Science Fiction'}, {'id'...                en
#
#                                 production_companies  \
# 0  [{'id': 34441, 'logo_path': None, 'name': 'Lit...
# 1  [{'id': 34441, 'logo_path': None, 'name': 'Lit...
# 2  [{'id': 19747, 'logo_path': None, 'name': 'Bra...
# 3  [{'id': 19747, 'logo_path': None, 'name': 'Bra...
# 4  [{'id': 19747, 'logo_path': None, 'name': 'Bra...
#
#                                 production_countries  collection_id
# 0  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...       458558.0
# 1  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...       458558.0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...         8091.0
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...         8091.0
# 4  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...         8091.0

# %%
def clean_awards(df, award_col_name):
    
    def parse_award_list(award):
        # only keeping first line    
        award = award.split("\n")[0].strip()
        # removing things surrounded by brackets
        award = re.sub("\(.*?\)|\[.*?\]","",award)
        return award   

    all_awards = []
    keywords = ["Best", "Most", "Top", "Worst", "Choice", "Original", "Favorite"]

    for index, row in df.iterrows():
        remade_awards = row[award_col_name]

        if type(remade_awards) == float:
            all_awards.append([])
            continue

        awards = remade_awards.split(",")
        x = list(map(parse_award_list,awards))
        x = list(filter(None, x))

        all_awards.append(x)

    new_list_of_all_awards = []    

    for awards in all_awards:
        new_list_of_awards = []
        for award in awards:   

            for keyword in keywords:
                if keyword in award:
                    new_list_of_awards.append(award)
                    continue
        new_list_of_all_awards.append(new_list_of_awards)
    return new_list_of_all_awards

# %%
sequels_imdb_df["Movie Awards"] = clean_awards(sequels_imdb_df, "Movie Awards")

# %% [markdown]
# Adding a column that stores the year a movie was released.

# %%
def get_year(date_string):
    if type(date_string) == str:
        return date_string[0:4]
    return None

# replacing NaNs and empty strings with "0000-00-00" so it can be convertd into a year
sequels_tmdb_df["release_date"] = (sequels_tmdb_df["release_date"].fillna("0000-00-00")
                                   .replace(r'^\s*$', "0000-00-00", regex=True))

year_col = sequels_tmdb_df["release_date"].apply(lambda x: get_year(x))
sequels_tmdb_df.insert(4, "release_year", year_col)
sequels_tmdb_df["release_year"].astype(int)

# replacing missing values with NaN
sequels_tmdb_df["release_year"] = sequels_tmdb_df["release_year"].replace("0000", np.nan, regex=True)

# changing year column from int to string 
sequels_tmdb_df["release_year"] = pd.to_numeric(sequels_tmdb_df["release_year"],errors="coerce")

sequels_tmdb_df = sequels_tmdb_df[sequels_tmdb_df["release_year"] < 2023]

# %% [markdown]
# Simplifying columns by turning dicts into lists.

# %%
def clean_list_of_dicts(list_of_dicts, dict_key):
    new_list = []
    for dict in list_of_dicts:
        new_list.append(dict[dict_key])
    return new_list

# %%
sequels_tmdb_df["production_companies"] = sequels_tmdb_df["production_companies"].apply(lambda x: clean_list_of_dicts(eval(x), "name"))
sequels_tmdb_df["production_countries"] = sequels_tmdb_df["production_countries"].apply(lambda x: clean_list_of_dicts(eval(x), "name"))
sequels_tmdb_df["genres"] = sequels_tmdb_df["genres"].apply(lambda x: clean_list_of_dicts(eval(x), "name"))

# %% [markdown]
# Merging IMDB and TMDB data using the IMDB ID.

# %%
sequels_df = pd.merge(sequels_tmdb_df, sequels_imdb_df, on = ["imdb_id"])

# %% [markdown]
# Putting the sequels and their corresponding original movies on the same row.

# %%
sequels_df = pd.merge(sequels_df[sequels_df["is_sequel"] == 0], sequels_df[sequels_df["is_sequel"] == 1], how='left' , on = "collection_id", suffixes = ('_original', '_sequel'))
sequels_df.drop(['is_sequel_original', 'is_sequel_sequel'], inplace=True, axis=1)

# %%
sequels_df
# Out:
#            title_original imdb_id_original  tmdb_id_original  \
# 0              Mamma Mia!        tt0795421             11631
# 1                   Alien        tt0078748               348
# 2                   Alien        tt0078748               348
# 3                   Alien        tt0078748               348
# 4                  Dr. No        tt0055928               646
# ...                   ...              ...               ...
# 2074          Çalgı Çengi        tt1865569             64468
# 2075            Vizontele        tt0270053             57892
# 2076  Helal Olsun Ali Abi        tt0388104            482483
# 2077    Magic Carpet Ride        tt0470883             30634
# 2078        Fool for Love        tt1630038            138969
#
#      release_date_original  release_year_original  runtime_original  \
# 0               2008-07-03                 2008.0               108
# 1               1979-05-25                 1979.0               117
# 2               1979-05-25                 1979.0               117
# 3               1979-05-25                 1979.0               117
# 4               1962-10-07                 1962.0               110
# ...                    ...                    ...               ...
# 2074            2011-02-18                 2011.0                90
# 2075            2001-02-02                 2001.0               110
# 2076            1963-10-31                 1963.0                 0
# 2077            2005-12-22                 2005.0               106
# 2078            2010-01-17                 2010.0               100
#
#       vote_average_original  vote_count_original  popularity_original  \
# 0                     6.966                 5868               29.600
# 1                     8.142                12773               47.437
# 2                     8.142                12773               47.437
# 3                     8.142                12773               47.437
# 4                     6.999                 3151               26.378
# ...                     ...                  ...                  ...
# 2074                  6.986                   71                3.099
# 2075                  7.200                  138                4.493
# 2076                  4.000                    1                1.371
# 2077                  6.706                  136                5.488
# 2078                  6.600                    4                0.600
#
#       budget_original  ...      Movie Budget_sequel  \
# 0            52000000  ...  $75,000,000 (estimated)
# 1            11000000  ...  $18,500,000 (estimated)
# 2            11000000  ...  $50,000,000 (estimated)
# 3            11000000  ...  $75,000,000 (estimated)
# 4             1200000  ...   $2,000,000 (estimated)
# ...               ...  ...                      ...
# 2074                0  ...                      NaN
# 2075                0  ...   $3,000,000 (estimated)
# 2076                0  ...  TRL 350,000 (estimated)
# 2077                0  ...                      NaN
# 2078                0  ...   $1,000,000 (estimated)
#
#      Movie Box Office US/CA_sequel Movie Box Office Worldwide_sequel  \
# 0                     $120,634,935                      $402,264,843
# 1                      $85,160,248                      $131,060,248
# 2                      $55,473,545                      $159,814,498
# 3                      $47,795,658                      $161,376,069
# 4                      $24,796,765                       $24,809,727
# ...                            ...                               ...
# 2074                           NaN                        $9,201,129
# 2075                           NaN                       $13,954,476
# 2076                           NaN                               NaN
# 2077                           NaN                       $10,327,763
# 2078                           NaN                               NaN
#
#      Movie Length_sequel Movie Rating_sequel  Movie Director Names_sequel  \
# 0                 1h 54m                 6.6                    Ol Parker
# 1                 2h 17m                 8.4                James Cameron
# 2                 1h 54m                 6.4                David Fincher
# 3                 1h 49m                 6.2           Jean-Pierre Jeunet
# 4                 1h 55m                 7.4                Terence Young
# ...                  ...                 ...                          ...
# 2074              1h 56m                 5.6               Selçuk Aydemir
# 2075              1h 51m                 6.5               Yilmaz Erdogan
# 2076              1h 12m                 7.2                  Hulki Saner
# 2077               2h 1m                 6.0               Yilmaz Erdogan
# 2078              1h 35m                 5.7               Charlie Nguyen
#
#                    Movie Director Links_sequel  \
# 0     ['https://www.imdb.com/name/nm0662530/']
# 1     ['https://www.imdb.com/name/nm0000116/']
# 2     ['https://www.imdb.com/name/nm0000399/']
# 3     ['https://www.imdb.com/name/nm0000466/']
# 4     ['https://www.imdb.com/name/nm0950109/']
# ...                                        ...
# 2074  ['https://www.imdb.com/name/nm3252853/']
# 2075  ['https://www.imdb.com/name/nm0258784/']
# 2076  ['https://www.imdb.com/name/nm0762517/']
# 2077  ['https://www.imdb.com/name/nm0258784/']
# 2078  ['https://www.imdb.com/name/nm1110306/']
#
#                                 Movie Cast Names_sequel  \
# 0             Lily James, Amanda Seyfried, Meryl Streep
# 1          Sigourney Weaver, Michael Biehn, Carrie Henn
# 2     Sigourney Weaver, Charles S. Dutton, Charles D...
# 3       Sigourney Weaver, Winona Ryder, Dominique Pinon
# 4                Sean Connery, Robert Shaw, Lotte Lenya
# ...                                                 ...
# 2074              Ahmet Kural, Murat Cemcir, Bahri Akin
# 2075         Yilmaz Erdogan, Demet Akbag, Altan Erkekli
# 2076              Sadri Alisik, Erol Amaç, Cemil Sahbaz
# 2077         Yilmaz Erdogan, Kivanç Tatlitug, Ezgi Mola
# 2078                  Thai Hoa, Cory Jackson, Huy Khanh
#
#                                 Movie Cast Links_sequel  \
# 0     ['https://www.imdb.com/name/nm4141252/', 'http...
# 1     ['https://www.imdb.com/name/nm0000244/', 'http...
# 2     ['https://www.imdb.com/name/nm0000244/', 'http...
# 3     ['https://www.imdb.com/name/nm0000244/', 'http...
# 4     ['https://www.imdb.com/name/nm0000125/', 'http...
# ...                                                 ...
# 2074  ['https://www.imdb.com/name/nm2899002/', 'http...
# 2075  ['https://www.imdb.com/name/nm0258784/', 'http...
# 2076  ['https://www.imdb.com/name/nm0019699/', 'http...
# 2077  ['https://www.imdb.com/name/nm0258784/', 'http...
# 2078  ['https://www.imdb.com/name/nm4642822/', 'http...
#
#                                     Movie Awards_sequel
# 0                                                    []
# 1     [Best Effects, Best Effects, Best Actress in a...
# 2                                        [Best Effects]
# 3                                 [Best DVD Collection]
# 4                        [Best British Cinematography ]
# ...                                                 ...
# 2074               [Best Movie Actor, Best Movie Actor]
# 2075  [Best Film, Best Screenplay, Best Cinematograp...
# 2076                                                 []
# 2077  [Best Movie Actor, Best Movie, Best Comedy Mov...
# 2078                                                 []
#
# [2079 rows x 51 columns]

# %% [markdown]
# Replacing missing budget/revenue information with NaNs.

# %%
sequels_df["budget_original"] = sequels_df["budget_original"].replace(0, np.nan)
sequels_df["budget_sequel"] = sequels_df["budget_sequel"].replace(0, np.nan)
sequels_df["revenue_original"] = sequels_df["revenue_original"].replace(0, np.nan)
sequels_df["revenue_sequel"] = sequels_df["revenue_sequel"].replace(0, np.nan)

# %% [markdown]
# Adding z-score columns.

# %%
sequels_df["z_vote_average_original"] = stats.zscore(sequels_df["vote_average_original"], nan_policy="omit")
sequels_df["z_vote_count_original"] = stats.zscore(sequels_df["vote_count_original"], nan_policy="omit")
sequels_df["z_popularity_original"] = stats.zscore(sequels_df["popularity_original"], nan_policy="omit")
sequels_df["z_budget_original"] = stats.zscore(sequels_df["budget_original"], nan_policy="omit")
sequels_df["z_revenue_original"] = stats.zscore(sequels_df["revenue_original"], nan_policy="omit")

sequels_df["z_vote_average_sequel"] = stats.zscore(sequels_df["vote_average_sequel"], nan_policy="omit")
sequels_df["z_vote_count_sequel"] = stats.zscore(sequels_df["vote_count_sequel"], nan_policy="omit")
sequels_df["z_popularity_sequel"] = stats.zscore(sequels_df["popularity_sequel"], nan_policy="omit")
sequels_df["z_budget_sequel"] = stats.zscore(sequels_df["budget_sequel"], nan_policy="omit")
sequels_df["z_revenue_sequel"] = stats.zscore(sequels_df["revenue_sequel"], nan_policy="omit")

# %%
sequels_df.to_csv("sequels_data.csv")
